# %% [markdown]
# # Lab 3: Artificial Neural Network from Scratch
#
# In this notebook we'll look get a good look implementing a simple neural network, or perceptron. Specifically, we will create a simple, single layer perceptron with only one feature for input.
#
# We'll build this from scratch, then compare it to logistic regression. After that, we'll use PyTorch's functionality to simplify everything - from calculating derivatives with the chain rule to the optimization itself.
#
# You can open this notebook in either Google Colab:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sgeinitz/CS3120/blob/main/lab03_ann_from_scratch.ipynb)
#
# or in Kaggle:
#
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/sgeinitz/CS3120/blob/main/lab03_ann_from_scratch.ipynb)
#
# ### 1: Generate Synthetic Data
# We'll first import the necessary Python modules and then generate synthetic data with appropriate size/dimensions. We'll also plot the generated data to see x and y. Note that the y outcomes/labels belong to one of two classes. The positive cases are shown in blue while negative cases are in red.

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

N = 100 # total number of observations
D_in = 1 # input dimension (i.e. dimension of a single observation's x vector)
D_out = 1 # output dimension (i.e. y), so just 1 for this example
random.seed(1)
np.random.RandomState(1)

# Create random input data and derive the 'true' labels/output
x = np.random.randn(N, D_in) + 1
def true_y(x_in, n_obs):
    def addNoise(x):
        if abs(x-1) < 1:
            return 0.1
        elif abs(x-1) < 0.1:
            return 0.25
        else:
            return 0.01

    return np.apply_along_axis(lambda x: [int(x[0] < 1) if random.random() < addNoise(x) else int(x[0] > 1)], 1, x_in)

y = true_y(x, N).flatten()

plt.scatter(x[y == 1,0], y[y == 1], c='blue', s=100, alpha=0.2)
plt.scatter(x[y == 0,0], y[y == 0], c='red', s=100, alpha=0.2)
plt.xlabel("x")
plt.ylabel("y")
plt.legend(('positive cases', 'negative cases'))
plt.show()

# %% [markdown]
# Let's quickly peek at the x and y data objects (i.e. numpy arrays) to see what their size, shape, and rank look like.

# %%
print(f"y.size: {y.size}")
print(f"y.shape: {y.shape}")
print(f"y.ndim: {y.ndim}")

print(f"x.size: {x.size}")
print(f"x.shape: {x.shape}")
print(f"x.ndim: {x.ndim}")
# Out:
# y.size: 100
# y.shape: (100,)
# y.ndim: 1
# x.size: 100
# x.shape: (100, 1)
# x.ndim: 2

# %% [markdown]
# ### 2a. Fit Logistic Regression Model
#
# We've already seen that a single layer perceptron with a sigmoid output activation function is equivalent to logisitic regression. So, before we start with the perceptron let's quickly review logistic regression by fitting it to the simulated data we created above.
#
# That is, let's find estimates for $\beta_0$ and $\beta_1$, which we'll need to be able to predict/estimate the probability that y is in the positive or negative class for any given x.
#
# In traditional statistics there is a large class of models known as [generalized linear models](https://en.wikipedia.org/wiki/Generalized_linear_model), which allow for a linear regression to be used to predict some transformation of the target variable. With logistic regression we transform the target variable, $Y$ (a binary 0 or 1) by looking at the log-odds of the expected value of $y_i$. If we let $p_i$ be the probability that $y_i$ equals 1, i.e., $p_i = P(y_i = 1)$, then the log-odds are as follows (note that the log-odds are formally known as the [logit](https://en.wikipedia.org/wiki/Logit) function):
#
# * $\mathrm{logit}(p_i) = ln\Big( \frac{p_i}{1 - p_i} \Big)= \beta_0 + \beta_1*x_i$
#
# Notice that the right side of the formula is in the familiar linear regression format of $\beta$ coefficients and their corresponding $x$ covariates.
#
# When it comes time to make a prediction for a new $y_i$, we'll then use the inverse of the logit function, which happens to be the logistic, or sigmoid, function:
#
# * $p_i = \mathrm{logit}^{-1}\Big( \mathrm{logit}(p_i) \Big) = \mathrm{logit}^{-1}(\beta_0 + \beta_1*x_i) = \frac{1}{1 + e^{-(\beta_0 + \beta_1*x_i)}}$

# %%
from sklearn.linear_model import LogisticRegression
logreg_model = LogisticRegression(random_state=42, max_iter=100, tol=1e-3, solver='liblinear')
logreg_model.fit(x, y)

print(f" beta0 = {logreg_model.intercept_[0]:.4f}")
print(f" beta1 = {logreg_model.coef_[0][0]:.4f}")
y_pred = logreg_model.predict_proba(x)
lr_loss = 1/N * np.square(y - y_pred[:,1]).sum()
print(f" loss (mse) = {lr_loss:.4f}")
# Out:
#  beta0 = -2.3725
#  beta1 = 2.4243
#  loss (mse) = 0.1036

# %% [markdown]
# To find those estimates scikit learn's LogisticRegression model solved an optimization problem that we are familiar with, which was to minimize the loss function. Recall that the mean-squared error loss function looks like this:
#
# * $\mathrm{Loss}_{MSE} = \frac{1}{N} \sum_i^N (y_i - p_i)^2$
#
#
# Note that we've sometimes used $\hat{y}_i$ instead of $p_i$, but they typically considered to be the same quantity (i.e. the direct output of the model).
#
# If we state $p_i$ in terms of our model parameters then, as seen above, we have the following:
#
# * $ \mathrm{Loss}_{MSE} = \frac{1}{N} \sum_i^N \Big( y_i - (1 + e^{-(\beta_0 + \beta_1*x_i)})^{-1} \Big)^2$
#
# By writing the loss function as a function of our model parameters, we can then plot the surface of the loss with $\beta_0$ and $\beta_1$ on the x and y axes, respectively. We can then see where the optimal values might be. Remember that in practice, when we have hundreds, thousands, or more, model parameters, that it is impossible to plot the loss surface in this way.

# %%
#b1s = np.arange(6, -4.1, -0.5)
#b0s = np.arange(-6, 4.1, 0.5)
b1s = np.arange(9, -5, -0.25)
b0s = np.arange(-9, 5, 0.25)
surf = np.array( [[1/N * np.square(y - 1 / (1 + np.exp(-1 * (b1s[i]*x[:,0] + b0s[j])))).sum() for j in range(len(b0s))] for i in range(len(b1s))] )
df = pd.DataFrame(surf, columns=b0s, index=b1s)
p1 = sns.heatmap(df, cbar_kws={'label': 'loss'}, cmap="RdYlGn_r")
plt.title("Loss surface")
plt.xlabel("beta0")
plt.ylabel("beta1")
plt.show()

# %% [markdown]
# Notice above that there does not appear to be one unique pair of values for $\beta_0$, $\beta_1$ that will yield a minimum loss value. That is to say, there is no single point on the surface we plotted above where the loss has an obvivous global minimum. Instead, it looks as if the loss continues to decrease as $\beta_0$ gets smaller and $\beta_1$ gets larger.
#
# What would happen if we chose to use another loss function? Would the log-loss (aka binary cross-entropy) function look much different? The log-loss, or binary cross-entropy function is defined as follows.
#
# * $\mathrm{Loss}_{BCE} = - \sum_i^N \Big( y_i * \mathrm{ln}(\hat{y}_i) + (1 - y_i)*\mathrm{ln}(1-\hat{y}_i) \Big)$
#
# This is a different looking function altogether from the MSE. We would expect, however, that the surface would be similar though so that we would ultimately find similar parameter values. Let's plot this now to see. (Note that in practice the log-loss is the loss function typically used for logistic regression models.)

# %%
#b1s = np.arange(9, -4.1, -0.5)
#b0s = np.arange(-9, 4.1, 0.5)
b1s = np.arange(9, -5, -0.25)
b0s = np.arange(-9, 5, 0.25)
surf = np.array( [[ -((y * np.log2(1 / (1 + np.exp(-1 * (b1s[i]*x[:,0] + b0s[j])))) + (1-y) * np.log2(1 - 1 / (1 + np.exp(-1 * (b1s[i]*x[:,0] + b0s[j])))))/100).sum() for j in range(len(b0s))] for i in range(len(b1s))] )
df = pd.DataFrame(surf, columns=b0s, index=b1s)
p1 = sns.heatmap(df, cbar_kws={'label': 'loss'}, cmap="RdYlGn_r")
plt.xlabel("beta0")
plt.ylabel("beta1")
plt.show()

# %% [markdown]
# Although the two surfaces are noticeably distinct from one another, they do appear to agree on what values of the parameters will minimize the loss. It appears that in both cases the loss will be minimized when $\beta_0$ is a small value (far to the left on the graph) and $\beta_1$ is a large value (up high on the graph).

# %% [markdown]
# ### 2b: Predict y for a Newly Observed x
#
# Let's see now what the model looks like using the parameter estimates found above (i.e. $\beta_0 = -2.17$, $\beta_1 = 2.55$). Next let's assume we are given a new observation to make a prediction for, and for this new observation we have $x = 1.5$. We can then predict whether it is a positive or negative case by evaluating the logistic function at $x = 1.2$. This yields $\hat{y} \approx 0.7$ (see below).
#
# Since $0.5$ is the typical cutoff value for predicting a positive (vs negative label), and $0.7 > 0.5$, we would likely predict this to be a positive case.
#
# __TIP:__ Try changing the values of the model parameters $\beta_0$ and $\beta_1$ below. Using the plots of the loss surfaces above, try choosing values of the model parameters look like they will yield an even lower point on the surface (i.e. smaller value of loss function). What happens to the plot below when doing so?

# %%
b0 = -2.16
b1 = 2.55

plt.scatter(x[y == 1,0], y[y == 1], c='blue', alpha=0.4)
plt.scatter(x[y == 0,0], y[y == 0], c='red', alpha=0.4)
plt.xlabel("x")
plt.ylabel("y")

x_new = 1.2
y_hat_new = 1 / (1 + np.exp(-b0 - b1*x_new))
plt.scatter(x_new, y_hat_new, color="green")
plt.legend(('positive cases', 'negative cases', 'new prediction'), loc='upper left')

xes = np.arange(-4, 4, 0.2)
plt.plot(xes, 1/(1 + np.exp(-b0 - b1*xes)), 'k--')

plt.show()
y_hat_new
# Out:
# np.float64(0.7109495026250039)

# %% [markdown]
# ### 2c. Why not use Accuracy for Optimization? (instead of MSE or BCE)
#
# At some point you may have asked yourself, "_Why don't we just train our model by optimizing for accuracy?_"
#
# Below is a plot of the surface when using accuracy as the function that the model will optimize for during training. Run the following cell and then answer the questions below.

# %%
b1s = np.arange(9, -5, -0.25)
b0s = np.arange(-9, 5, 0.25)
def accuracy(b0, b1):
    # calculate the model output for this b0 and b1
    y_hat = 1 / (1 + np.exp(-b0 - b1 * x.flatten()))
    # convert the model output to binary predictions
    y_hat = np.round(y_hat)
    return np.sum(y == y_hat) / len(y)
surf = np.array( [[ accuracy(b0s[j], b1s[i]) for j in range(len(b0s))] for i in range(len(b1s))] )
df = pd.DataFrame(surf, columns=b0s, index=b1s)
p1 = sns.heatmap(df, cbar_kws={'label': 'accuracy'}, cmap="RdYlGn_r")
plt.xlabel("beta0")
plt.ylabel("beta1")
plt.show()

# %% [markdown]
# ***
# ### Q1: What is different about using accuracy versus a loss function (e.g. MSE or BCE)?
# (Hint: What are the ranges of values that accuracy takes on versus the loss functions? And, which are considered _good_ and which are considered _bad_?)
#
# \<INPUT YOUR ANSWER TO Q1 HERE\>
# ***
#
#
# To start, accuracy behaves differently than MSE or BCE since it is discrete and flat while only taking values between 0 and 1. Small changes within the model parameters usually don’t change accuracy, so it fails to provide a useful gradient for optimization. However, loss functions such as MSE or BCE vary smoothly over a wider range of values and reflect the degree of error.

# %% [markdown]
# ***
# ### Q2: Assuming you account for what is different about using accuracy versus a loss function, there is still something wrong with using accuracy. What is it? That is, why wouldn't you use accuracy to train a neural network model?
# (Hint: How does the accuracy surface differ from the MSE or BCE surfaces? What happens right around b=0, w=0?)
#
# \<INPUT YOUR ANSWER TO Q2 HERE\>
# ***
# You would not want to utilize accuracy since it is known to be flat and discontinuous. In contrast, MSE and BCE are not known for that sentiment, as they both produce smooth and continuous surfaces where small parameter changes yield small but meaningful changes within the loss. This allows the gradient descent to find direction to move, in accordance with the change. An example of accuracy being in a flat state would be when b=0, w=0 which results in the model predicting the same class for each data point. This results in the predicted class being constant which results in constant accuracy values.

# %% [markdown]
# ### 3. Simple Perceptron w/ NumPy
#
# Using the same $x$ and $y$ data as before we will now see how a simple perceptron network with a sigmoid activiation function is equivalent to the logistic regression model above. Rather than $\beta_0$, $\beta_1$, the parameters to be estimated are generally referred to as the weight and bias terms ($w$ and $b$, respectively). For this simple case they differ only in name though, such that:
# * $b = \beta_0$
# * $w = \beta_1$
#
# To begin we will manually train the perceptron using numpy and gradient descent to minimize the loss. This will involve taking the derivatives of $w$ and $b$ (using the chain rule) to calculate the gradients in an interative process.

# %%
# Randomly initialize parameters to be estimated
np.random.seed(42)
w = np.random.randn(1)
b = np.random.randn(1)

# learning rate parameter
learning_rate = 5e-1

# keep track of loss to see how the optimization performs
loss = []

params = []

# Begin gradient descent using all of the observations in each iteration
for i in range(250):

    params.append((w[0], b[0]))

    # Forward pass: compute predicted y
    lin_pred = w[0] * x[:,0] + b[0]
    y_pred = 1 / (1 + np.exp(-1 * lin_pred))

    # Compute and store loss, and print occassionally
    loss.append(1/N * np.square(y - y_pred).sum())
    if i % 50 == 0:
        print(f"iteration {i}: loss = {loss[i]:.4f}, w = {w[0]:.4f}, b = {b[0]:.4f}")

    # Backprop to compute gradients of w and b with respect to log loss
    dloss_dypred = -2.0 / N * (y - y_pred)
    dypred_dlinpred = np.exp(-lin_pred) * (1 / np.square(1 + np.exp(-1 * lin_pred)))
    dlinpred_dw = x[:,0]
    dlinpred_db = 1

    # Calculate gradients and update weight and bias parameters
    grad_w = (dloss_dypred * dypred_dlinpred * dlinpred_dw).sum()
    grad_b = (dloss_dypred * dypred_dlinpred * dlinpred_db).sum()
    w -= learning_rate * grad_w # calculate w^(k+1) from w^(k)
    b -= learning_rate * grad_b # calculate b^(k+1) from b^(k)

print(f" w = {w.item():.4f}")
print(f" b = {b.item():.4f}")

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,4))
ax1.plot(range(0,len(loss)), loss)
ax1.set(xlabel="optimization iteration", ylabel="loss")
ax2.plot(range(0,len(params)), [parm[0] for parm in params])
ax2.set(xlabel="optimization iteration", ylabel="parameter: w")
ax3.plot(range(0,len(params)), [parm[1] for parm in params])
ax3.set(xlabel="optimization iteration", ylabel="parameter: b")
# Out:
# iteration 0: loss = 0.1974, w = 0.4967, b = -0.1383
# iteration 50: loss = 0.1355, w = 1.2429, b = -1.0983
# iteration 100: loss = 0.1186, w = 1.6607, b = -1.5898
# iteration 150: loss = 0.1111, w = 1.9478, b = -1.9157
# iteration 200: loss = 0.1068, w = 2.1658, b = -2.1591
#  w = 2.3413
#  b = -2.3532
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]

# %% [markdown]
# ***
# ### Q3: Try running the above code cell a few times. Do you get the exact same parameter value estimates for $b$ and $w$ each time? Explain why or why not?
#
# \<INPUT YOUR ANSWER TO Q3 HERE\>
# ***
#
# iteration 0: loss = 0.4592, w = -1.5868, b = -0.6004
# iteration 50: loss = 0.1486, w = 0.8445, b = -0.7518
# iteration 100: loss = 0.1108, w = 1.4441, b = -1.4954
# iteration 150: loss = 0.0985, w = 1.7944, b = -1.9205
# iteration 200: loss = 0.0925, w = 2.0451, b = -2.2156
#  w = 2.2403
#  b = -2.4415
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]
#
#
# iteration 0: loss = 0.3103, w = -0.2916, b = -0.5675
# iteration 50: loss = 0.1217, w = 1.2250, b = -1.2196
# iteration 100: loss = 0.1029, w = 1.6525, b = -1.7503
# iteration 150: loss = 0.0948, w = 1.9402, b = -2.0929
# iteration 200: loss = 0.0904, w = 2.1571, b = -2.3457
#  w = 2.3313
#  b = -2.5459
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]
#
# iteration 0: loss = 0.1936, w = 0.3715, b = -0.3698
# iteration 50: loss = 0.1187, w = 1.2803, b = -1.2898
# iteration 100: loss = 0.1017, w = 1.6871, b = -1.7920
# iteration 150: loss = 0.0942, w = 1.9653, b = -2.1225
# iteration 200: loss = 0.0900, w = 2.1769, b = -2.3685
#  w = 2.3476
#  b = -2.5645
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]
#
#
# As evidenced by the three code cell outputs above, we can see that we fail to yield the same parameter value estimates for b and w for each time we run the code block. This is mainly due to the commenting out of” np.random.seed(42)” which if it were not commented out would allow for the code block to run at the same spot each time. Whereas currently each run results in starting a different locations within the “loss surface”, which results in changing values.

# %% [markdown]
# ### 4. Simple Perceptron w/ PyTorch
#
# Now we will train a basic perceptron using PyTorch to take advantage of its ability to perform automatic differentation. This allows us to avoid calculating derivatives manually.

# %%
import torch

# Randomly initialize weights and other data
#torch.manual_seed(42)
w = torch.randn(1, requires_grad=True)
b = torch.randn(1, requires_grad=True)
x_tensor = torch.tensor(x)
y_tensor = torch.tensor(y)
learning_rate = 5e-1
losses = []
params = []

# Carry out gradient descent
for i in range(250):

    params.append((w.item(), b.item()))

    # Forward pass: compute predicted y
    lin_pred = w * x_tensor + b
    y_pred = lin_pred.flatten().sigmoid()

    # Compute and store loss, and print occassionally
    loss = 1/N * (y_tensor - y_pred).pow(2).sum()
    losses.append(loss.item())
    if i % 50 == 0:
        print(f"iteration {i}: loss = {loss.item():.4f}, w = {w[0]:.4f}, b = {b[0]:.4f}")

    loss.backward()

    # Update parameters but don't include these calculations as part of underlying computational graph
    with torch.no_grad():
        w -= learning_rate * w.grad
        b -= learning_rate * b.grad

    # Reset gradients for next iteration
    w.grad.zero_()
    b.grad.zero_()

print(f" w = {w.item():.4f}")
print(f" b = {b.item():.4f}")

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,4))
ax1.plot(range(0,len(losses)), losses)
ax1.set(xlabel="optimization iteration", ylabel="loss")
ax2.plot(range(0,len(params)), [parm[0] for parm in params])
ax2.set(xlabel="optimization iteration", ylabel="parameter: w")
ax3.plot(range(0,len(params)), [parm[1] for parm in params])
ax3.set(xlabel="optimization iteration", ylabel="parameter: b")
# Out:
# iteration 0: loss = 0.4449, w = -1.0368, b = -0.7703
# iteration 50: loss = 0.1448, w = 1.0784, b = -0.8992
# iteration 100: loss = 0.1220, w = 1.5589, b = -1.4725
# iteration 150: loss = 0.1128, w = 1.8744, b = -1.8331
# iteration 200: loss = 0.1078, w = 2.1086, b = -2.0956
#  w = 2.2946
#  b = -2.3016
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]

# %% [markdown]
# ***
# ### Q4: Run the above code a cell a few times and then try to read it to understand what is happening. Specifically, state which line(s) is calculating the gradients?
# Note that the gradients are the derivatives of the objective function with respect to the model parameters (that are then evaluated at the current values of the parameters).
#
#
# \<INPUT YOUR ANSWER TO Q4 HERE\>
# ***
#
# The lines that are calculating the gradients are:
# "
#
#     with torch.no_grad():
#         w -= learning_rate * w.grad
#         b -= learning_rate * b.grad
#
# "
#
# This is evidenced by
# w.grad and b.grad being the gradients of the loss function being computed by loss.backword just prior to their occurrence; and learning rate is the step size which controls how large each update is.

# %% [markdown]
# ### 5: Defining a Perceptron w/ PyTorch
#
# Now we will train a basic perceptron using PyTorch to define the model architecture itself, while continuing to take advantage of its automatic differentation.

# %%
# Randomly initialize weights and other data
torch.manual_seed(42)
#del w #= torch.randn(1, requires_grad=True).reshape(1,1)
#del b #b = torch.randn(1, requires_grad=True).reshape(1,1)
x_tensor = torch.tensor(x).float()
y_tensor = torch.tensor(y).float().reshape(N, D_out)

# Define and declare a pytorch perceptron using sigmoid activation function
model = torch.nn.Sequential(
    torch.nn.Linear(1, 1), # linear layer
    torch.nn.Sigmoid()     # activation function
)

# Define loss function to be used
loss_fn = torch.nn.MSELoss()

learning_rate = 5e-1
losses = []
params = []

# Carry out gradient descent
for i in range(250):

    params.append(tuple([param.item() for param in model.parameters()]))

    # Forward pass: compute predicted y
    y_pred = model.forward(x_tensor)

    # Compute and store loss, and print occassionally
    loss = loss_fn(y_pred, y_tensor)
    losses.append(loss.item())
    if i % 50 == 0:
        print(f"iteration {i}: loss = {loss.item():.4f}")

    model.zero_grad()

    # Backprop using PyTorch's automatic differentiation
    loss.backward()

    # Update parameters but don't include these calculations as part of underlying computational graph
    with torch.no_grad():
        for param in model.parameters():
            param.data -= learning_rate * param.grad

print("parameter values after training:")
for i, param in enumerate(model.parameters()):
    print(f"  param {i} est = {param.item():.4f}")

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,4))
ax1.plot(range(0,len(losses)), losses)
ax1.set(xlabel="optimization iteration", ylabel="loss")
ax2.plot(range(0,len(params)), [parm[0] for parm in params])
ax2.set(xlabel="optimization iteration", ylabel="parameter: w")
ax3.plot(range(0,len(params)), [parm[1] for parm in params])
ax3.set(xlabel="optimization iteration", ylabel="parameter: b")
# Out:
# iteration 0: loss = 0.3002
# iteration 50: loss = 0.1463
# iteration 100: loss = 0.1225
# iteration 150: loss = 0.1130
# iteration 200: loss = 0.1079
# parameter values after training:
#   param 0 est = 2.2884
#   param 1 est = -2.2948
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]

# %% [markdown]
# ***
# ### Q5: Run the above code a cell a few times and then try to read it to understand what is happening. Specifically, state which line(s) is carrying out the Gradient Descent update?
#
#
# \<INPUT YOUR ANSWER TO Q5 HERE\>
# ***
#
# The lines that are carrying out the gradient descent update are:
#
#     with torch.no_grad():
#         for param in model.parameters():
#             param.data -= learning_rate * param.grad

# %% [markdown]
# ### 6. Using PyTorch Optimizer
#
# Now we will train a basic perceptron using PyTorch to define the model itself and also to carry out the Adam optimization method (a extension of gradient descent that adaptively estimates gradients to be able to find minima more quickly).

# %%
# Randomly initialize weights and other data
torch.manual_seed(42)
x_tensor = torch.tensor(x).float()
y_tensor = torch.tensor(y).float().reshape(N, D_out)

# Declare a perceptron instance
model = torch.nn.Sequential(
    torch.nn.Linear(D_in, D_out),
    torch.nn.Sigmoid()
)


# Define loss function to be used
#loss_fn = torch.nn.MSELoss()
loss_fn = torch.nn.BCELoss()

#learning_rate = 0.05
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

losses = []
params = []

# Carry out gradient descent
for i in range(50000 + 1):

    params.append(tuple([param.item() for param in model.parameters()]))

    # Forward pass: compute predicted y
    y_pred = model.forward(x_tensor)

    # Compute and store loss, and print occassionally
    loss = loss_fn(y_pred, y_tensor)
    losses.append(loss.item())
    if i % 50 == 0:
        print(f"iteration {i}: loss = {loss.item():.4f}")

    # Zero all gradients before backward pass
    optimizer.zero_grad()

    # Backprop then call optimizer step to update all (relevant) model parameters for us
    loss.backward()
    optimizer.step() # this calculates w(k+1) for us (for all parameters)

print("w and b estimates:")
for param in model.parameters():
    print(f"    {param.item():.4f}")

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,4))
ax1.plot(range(0,len(losses)), losses)
ax1.set(xlabel="optimization iteration", ylabel="loss")
ax2.plot(range(0,len(params)), [parm[0] for parm in params])
ax2.set(xlabel="optimization iteration", ylabel="parameter: w")
ax3.plot(range(0,len(params)), [parm[1] for parm in params])
ax3.set(xlabel="optimization iteration", ylabel="parameter: b")
# Out:
# iteration 0: loss = 0.7997
# iteration 50: loss = 0.7789
# iteration 100: loss = 0.7599
# iteration 150: loss = 0.7429
# iteration 200: loss = 0.7277
# iteration 250: loss = 0.7141
# iteration 300: loss = 0.7020
# iteration 350: loss = 0.6910
# iteration 400: loss = 0.6808
# iteration 450: loss = 0.6712
# iteration 500: loss = 0.6620
# iteration 550: loss = 0.6531
# iteration 600: loss = 0.6443
# iteration 650: loss = 0.6357
# iteration 700: loss = 0.6273
# iteration 750: loss = 0.6190
# iteration 800: loss = 0.6109
# iteration 850: loss = 0.6029
# iteration 900: loss = 0.5951
# iteration 950: loss = 0.5874
# iteration 1000: loss = 0.5799
# iteration 1050: loss = 0.5726
# iteration 1100: loss = 0.5655
# iteration 1150: loss = 0.5585
# iteration 1200: loss = 0.5517
# iteration 1250: loss = 0.5450
# iteration 1300: loss = 0.5386
# iteration 1350: loss = 0.5322
# iteration 1400: loss = 0.5261
# iteration 1450: loss = 0.5201
# iteration 1500: loss = 0.5142
# iteration 1550: loss = 0.5086
# iteration 1600: loss = 0.5030
# iteration 1650: loss = 0.4976
# iteration 1700: loss = 0.4924
# iteration 1750: loss = 0.4872
# iteration 1800: loss = 0.4823
# iteration 1850: loss = 0.4774
# iteration 1900: loss = 0.4727
# iteration 1950: loss = 0.4681
# iteration 2000: loss = 0.4636
# iteration 2050: loss = 0.4593
# iteration 2100: loss = 0.4550
# iteration 2150: loss = 0.4509
# iteration 2200: loss = 0.4469
# iteration 2250: loss = 0.4430
# iteration 2300: loss = 0.4391
# iteration 2350: loss = 0.4354
# iteration 2400: loss = 0.4318
# iteration 2450: loss = 0.4283
# iteration 2500: loss = 0.4249
# iteration 2550: loss = 0.4215
# iteration 2600: loss = 0.4182
# iteration 2650: loss = 0.4151
# iteration 2700: loss = 0.4120
# iteration 2750: loss = 0.4090
# iteration 2800: loss = 0.4060
# iteration 2850: loss = 0.4032
# iteration 2900: loss = 0.4004
# iteration 2950: loss = 0.3976
# iteration 3000: loss = 0.3950
# iteration 3050: loss = 0.3924
# iteration 3100: loss = 0.3899
# iteration 3150: loss = 0.3874
# iteration 3200: loss = 0.3850
# iteration 3250: loss = 0.3827
# iteration 3300: loss = 0.3804
# iteration 3350: loss = 0.3782
# iteration 3400: loss = 0.3760
# iteration 3450: loss = 0.3739
# iteration 3500: loss = 0.3718
# iteration 3550: loss = 0.3698
# iteration 3600: loss = 0.3678
# iteration 3650: loss = 0.3659
# iteration 3700: loss = 0.3641
# iteration 3750: loss = 0.3622
# iteration 3800: loss = 0.3604
# iteration 3850: loss = 0.3587
# iteration 3900: loss = 0.3570
# iteration 3950: loss = 0.3554
# iteration 4000: loss = 0.3537
# iteration 4050: loss = 0.3522
# iteration 4100: loss = 0.3506
# iteration 4150: loss = 0.3491
# iteration 4200: loss = 0.3477
# iteration 4250: loss = 0.3462
# iteration 4300: loss = 0.3448
# iteration 4350: loss = 0.3435
# iteration 4400: loss = 0.3421
# iteration 4450: loss = 0.3409
# iteration 4500: loss = 0.3396
# iteration 4550: loss = 0.3384
# iteration 4600: loss = 0.3372
# iteration 4650: loss = 0.3360
# iteration 4700: loss = 0.3348
# iteration 4750: loss = 0.3337
# iteration 4800: loss = 0.3326
# iteration 4850: loss = 0.3316
# iteration 4900: loss = 0.3305
# iteration 4950: loss = 0.3295
# iteration 5000: loss = 0.3285
# iteration 5050: loss = 0.3276
# iteration 5100: loss = 0.3266
# iteration 5150: loss = 0.3257
# iteration 5200: loss = 0.3248
# iteration 5250: loss = 0.3240
# iteration 5300: loss = 0.3231
# iteration 5350: loss = 0.3223
# iteration 5400: loss = 0.3215
# iteration 5450: loss = 0.3207
# iteration 5500: loss = 0.3199
# iteration 5550: loss = 0.3192
# iteration 5600: loss = 0.3185
# iteration 5650: loss = 0.3178
# iteration 5700: loss = 0.3171
# iteration 5750: loss = 0.3164
# iteration 5800: loss = 0.3158
# iteration 5850: loss = 0.3151
# iteration 5900: loss = 0.3145
# iteration 5950: loss = 0.3139
# iteration 6000: loss = 0.3133
# iteration 6050: loss = 0.3128
# iteration 6100: loss = 0.3122
# iteration 6150: loss = 0.3117
# iteration 6200: loss = 0.3112
# iteration 6250: loss = 0.3107
# iteration 6300: loss = 0.3102
# iteration 6350: loss = 0.3097
# iteration 6400: loss = 0.3092
# iteration 6450: loss = 0.3088
# iteration 6500: loss = 0.3083
# iteration 6550: loss = 0.3079
# iteration 6600: loss = 0.3075
# iteration 6650: loss = 0.3071
# iteration 6700: loss = 0.3067
# iteration 6750: loss = 0.3064
# iteration 6800: loss = 0.3060
# iteration 6850: loss = 0.3056
# iteration 6900: loss = 0.3053
# iteration 6950: loss = 0.3050
# iteration 7000: loss = 0.3047
# iteration 7050: loss = 0.3044
# iteration 7100: loss = 0.3041
# iteration 7150: loss = 0.3038
# iteration 7200: loss = 0.3035
# iteration 7250: loss = 0.3032
# iteration 7300: loss = 0.3030
# iteration 7350: loss = 0.3027
# iteration 7400: loss = 0.3025
# iteration 7450: loss = 0.3023
# iteration 7500: loss = 0.3020
# iteration 7550: loss = 0.3018
# iteration 7600: loss = 0.3016
# iteration 7650: loss = 0.3014
# iteration 7700: loss = 0.3012
# iteration 7750: loss = 0.3011
# iteration 7800: loss = 0.3009
# iteration 7850: loss = 0.3007
# iteration 7900: loss = 0.3006
# iteration 7950: loss = 0.3004
# iteration 8000: loss = 0.3003
# iteration 8050: loss = 0.3001
# iteration 8100: loss = 0.3000
# iteration 8150: loss = 0.2999
# iteration 8200: loss = 0.2997
# iteration 8250: loss = 0.2996
# iteration 8300: loss = 0.2995
# iteration 8350: loss = 0.2994
# iteration 8400: loss = 0.2993
# iteration 8450: loss = 0.2992
# iteration 8500: loss = 0.2991
# iteration 8550: loss = 0.2990
# iteration 8600: loss = 0.2990
# iteration 8650: loss = 0.2989
# iteration 8700: loss = 0.2988
# iteration 8750: loss = 0.2987
# iteration 8800: loss = 0.2987
# iteration 8850: loss = 0.2986
# iteration 8900: loss = 0.2986
# iteration 8950: loss = 0.2985
# iteration 9000: loss = 0.2985
# iteration 9050: loss = 0.2984
# iteration 9100: loss = 0.2984
# iteration 9150: loss = 0.2983
# iteration 9200: loss = 0.2983
# iteration 9250: loss = 0.2982
# iteration 9300: loss = 0.2982
# iteration 9350: loss = 0.2982
# iteration 9400: loss = 0.2982
# iteration 9450: loss = 0.2981
# iteration 9500: loss = 0.2981
# iteration 9550: loss = 0.2981
# iteration 9600: loss = 0.2981
# iteration 9650: loss = 0.2980
# iteration 9700: loss = 0.2980
# iteration 9750: loss = 0.2980
# iteration 9800: loss = 0.2980
# iteration 9850: loss = 0.2980
# iteration 9900: loss = 0.2980
# iteration 9950: loss = 0.2980
# iteration 10000: loss = 0.2980
# iteration 10050: loss = 0.2979
# iteration 10100: loss = 0.2979
# iteration 10150: loss = 0.2979
# iteration 10200: loss = 0.2979
# iteration 10250: loss = 0.2979
# iteration 10300: loss = 0.2979
# iteration 10350: loss = 0.2979
# iteration 10400: loss = 0.2979
# iteration 10450: loss = 0.2979
# iteration 10500: loss = 0.2979
# iteration 10550: loss = 0.2979
# iteration 10600: loss = 0.2979
# iteration 10650: loss = 0.2979
# iteration 10700: loss = 0.2979
# iteration 10750: loss = 0.2979
# iteration 10800: loss = 0.2979
# iteration 10850: loss = 0.2979
# iteration 10900: loss = 0.2979
# iteration 10950: loss = 0.2979
# iteration 11000: loss = 0.2979
# iteration 11050: loss = 0.2979
# iteration 11100: loss = 0.2979
# iteration 11150: loss = 0.2979
# iteration 11200: loss = 0.2979
# iteration 11250: loss = 0.2979
# iteration 11300: loss = 0.2979
# iteration 11350: loss = 0.2979
# iteration 11400: loss = 0.2979
# iteration 11450: loss = 0.2979
# iteration 11500: loss = 0.2979
# iteration 11550: loss = 0.2979
# iteration 11600: loss = 0.2979
# iteration 11650: loss = 0.2979
# iteration 11700: loss = 0.2979
# iteration 11750: loss = 0.2979
# iteration 11800: loss = 0.2979
# iteration 11850: loss = 0.2979
# iteration 11900: loss = 0.2979
# iteration 11950: loss = 0.2979
# iteration 12000: loss = 0.2979
# iteration 12050: loss = 0.2979
# iteration 12100: loss = 0.2979
# iteration 12150: loss = 0.2979
# iteration 12200: loss = 0.2979
# iteration 12250: loss = 0.2979
# iteration 12300: loss = 0.2979
# iteration 12350: loss = 0.2979
# iteration 12400: loss = 0.2979
# iteration 12450: loss = 0.2979
# iteration 12500: loss = 0.2979
# iteration 12550: loss = 0.2979
# iteration 12600: loss = 0.2979
# iteration 12650: loss = 0.2979
# iteration 12700: loss = 0.2979
# iteration 12750: loss = 0.2979
# iteration 12800: loss = 0.2979
# iteration 12850: loss = 0.2979
# iteration 12900: loss = 0.2979
# iteration 12950: loss = 0.2979
# iteration 13000: loss = 0.2979
# iteration 13050: loss = 0.2979
# iteration 13100: loss = 0.2979
# iteration 13150: loss = 0.2979
# iteration 13200: loss = 0.2979
# iteration 13250: loss = 0.2979
# iteration 13300: loss = 0.2979
# iteration 13350: loss = 0.2979
# iteration 13400: loss = 0.2979
# iteration 13450: loss = 0.2979
# iteration 13500: loss = 0.2979
# iteration 13550: loss = 0.2979
# iteration 13600: loss = 0.2979
# iteration 13650: loss = 0.2979
# iteration 13700: loss = 0.2979
# iteration 13750: loss = 0.2979
# iteration 13800: loss = 0.2979
# iteration 13850: loss = 0.2979
# iteration 13900: loss = 0.2979
# iteration 13950: loss = 0.2979
# iteration 14000: loss = 0.2979
# iteration 14050: loss = 0.2979
# iteration 14100: loss = 0.2979
# iteration 14150: loss = 0.2979
# iteration 14200: loss = 0.2979
# iteration 14250: loss = 0.2979
# iteration 14300: loss = 0.2979
# iteration 14350: loss = 0.2979
# iteration 14400: loss = 0.2979
# iteration 14450: loss = 0.2979
# iteration 14500: loss = 0.2979
# iteration 14550: loss = 0.2979
# iteration 14600: loss = 0.2979
# iteration 14650: loss = 0.2979
# iteration 14700: loss = 0.2979
# iteration 14750: loss = 0.2979
# iteration 14800: loss = 0.2979
# iteration 14850: loss = 0.2979
# iteration 14900: loss = 0.2979
# iteration 14950: loss = 0.2979
# iteration 15000: loss = 0.2979
# iteration 15050: loss = 0.2979
# iteration 15100: loss = 0.2979
# iteration 15150: loss = 0.2979
# iteration 15200: loss = 0.2979
# iteration 15250: loss = 0.2979
# iteration 15300: loss = 0.2979
# iteration 15350: loss = 0.2979
# iteration 15400: loss = 0.2979
# iteration 15450: loss = 0.2979
# iteration 15500: loss = 0.2979
# iteration 15550: loss = 0.2979
# iteration 15600: loss = 0.2979
# iteration 15650: loss = 0.2979
# iteration 15700: loss = 0.2979
# iteration 15750: loss = 0.2979
# iteration 15800: loss = 0.2979
# iteration 15850: loss = 0.2979
# iteration 15900: loss = 0.2979
# iteration 15950: loss = 0.2979
# iteration 16000: loss = 0.2979
# iteration 16050: loss = 0.2979
# iteration 16100: loss = 0.2979
# iteration 16150: loss = 0.2979
# iteration 16200: loss = 0.2979
# iteration 16250: loss = 0.2979
# iteration 16300: loss = 0.2979
# iteration 16350: loss = 0.2979
# iteration 16400: loss = 0.2979
# iteration 16450: loss = 0.2979
# iteration 16500: loss = 0.2979
# iteration 16550: loss = 0.2979
# iteration 16600: loss = 0.2979
# iteration 16650: loss = 0.2979
# iteration 16700: loss = 0.2979
# iteration 16750: loss = 0.2979
# iteration 16800: loss = 0.2979
# iteration 16850: loss = 0.2979
# iteration 16900: loss = 0.2979
# iteration 16950: loss = 0.2979
# iteration 17000: loss = 0.2979
# iteration 17050: loss = 0.2979
# iteration 17100: loss = 0.2979
# iteration 17150: loss = 0.2979
# iteration 17200: loss = 0.2979
# iteration 17250: loss = 0.2979
# iteration 17300: loss = 0.2979
# iteration 17350: loss = 0.2979
# iteration 17400: loss = 0.2979
# iteration 17450: loss = 0.2979
# iteration 17500: loss = 0.2979
# iteration 17550: loss = 0.2979
# iteration 17600: loss = 0.2979
# iteration 17650: loss = 0.2979
# iteration 17700: loss = 0.2979
# iteration 17750: loss = 0.2979
# iteration 17800: loss = 0.2979
# iteration 17850: loss = 0.2979
# iteration 17900: loss = 0.2979
# iteration 17950: loss = 0.2979
# iteration 18000: loss = 0.2979
# iteration 18050: loss = 0.2979
# iteration 18100: loss = 0.2979
# iteration 18150: loss = 0.2979
# iteration 18200: loss = 0.2979
# iteration 18250: loss = 0.2979
# iteration 18300: loss = 0.2979
# iteration 18350: loss = 0.2979
# iteration 18400: loss = 0.2979
# iteration 18450: loss = 0.2979
# iteration 18500: loss = 0.2979
# iteration 18550: loss = 0.2979
# iteration 18600: loss = 0.2979
# iteration 18650: loss = 0.2979
# iteration 18700: loss = 0.2979
# iteration 18750: loss = 0.2979
# iteration 18800: loss = 0.2979
# iteration 18850: loss = 0.2979
# iteration 18900: loss = 0.2979
# iteration 18950: loss = 0.2979
# iteration 19000: loss = 0.2979
# iteration 19050: loss = 0.2979
# iteration 19100: loss = 0.2979
# iteration 19150: loss = 0.2979
# iteration 19200: loss = 0.2979
# iteration 19250: loss = 0.2979
# iteration 19300: loss = 0.2979
# iteration 19350: loss = 0.2979
# iteration 19400: loss = 0.2979
# iteration 19450: loss = 0.2979
# iteration 19500: loss = 0.2979
# iteration 19550: loss = 0.2979
# iteration 19600: loss = 0.2979
# iteration 19650: loss = 0.2979
# iteration 19700: loss = 0.2979
# iteration 19750: loss = 0.2979
# iteration 19800: loss = 0.2979
# iteration 19850: loss = 0.2979
# iteration 19900: loss = 0.2979
# iteration 19950: loss = 0.2979
# iteration 20000: loss = 0.2979
# iteration 20050: loss = 0.2979
# iteration 20100: loss = 0.2979
# iteration 20150: loss = 0.2979
# iteration 20200: loss = 0.2979
# iteration 20250: loss = 0.2979
# iteration 20300: loss = 0.2979
# iteration 20350: loss = 0.2979
# iteration 20400: loss = 0.2979
# iteration 20450: loss = 0.2979
# iteration 20500: loss = 0.2979
# iteration 20550: loss = 0.2979
# iteration 20600: loss = 0.2979
# iteration 20650: loss = 0.2979
# iteration 20700: loss = 0.2979
# iteration 20750: loss = 0.2979
# iteration 20800: loss = 0.2979
# iteration 20850: loss = 0.2979
# iteration 20900: loss = 0.2979
# iteration 20950: loss = 0.2979
# iteration 21000: loss = 0.2979
# iteration 21050: loss = 0.2979
# iteration 21100: loss = 0.2979
# iteration 21150: loss = 0.2979
# iteration 21200: loss = 0.2979
# iteration 21250: loss = 0.2979
# iteration 21300: loss = 0.2979
# iteration 21350: loss = 0.2979
# iteration 21400: loss = 0.2979
# iteration 21450: loss = 0.2979
# iteration 21500: loss = 0.2979
# iteration 21550: loss = 0.2979
# iteration 21600: loss = 0.2979
# iteration 21650: loss = 0.2979
# iteration 21700: loss = 0.2979
# iteration 21750: loss = 0.2979
# iteration 21800: loss = 0.2979
# iteration 21850: loss = 0.2979
# iteration 21900: loss = 0.2979
# iteration 21950: loss = 0.2979
# iteration 22000: loss = 0.2979
# iteration 22050: loss = 0.2979
# iteration 22100: loss = 0.2979
# iteration 22150: loss = 0.2979
# iteration 22200: loss = 0.2979
# iteration 22250: loss = 0.2979
# iteration 22300: loss = 0.2979
# iteration 22350: loss = 0.2979
# iteration 22400: loss = 0.2979
# iteration 22450: loss = 0.2979
# iteration 22500: loss = 0.2979
# iteration 22550: loss = 0.2979
# iteration 22600: loss = 0.2979
# iteration 22650: loss = 0.2979
# iteration 22700: loss = 0.2979
# iteration 22750: loss = 0.2979
# iteration 22800: loss = 0.2979
# iteration 22850: loss = 0.2979
# iteration 22900: loss = 0.2979
# iteration 22950: loss = 0.2979
# iteration 23000: loss = 0.2979
# iteration 23050: loss = 0.2979
# iteration 23100: loss = 0.2979
# iteration 23150: loss = 0.2979
# iteration 23200: loss = 0.2979
# iteration 23250: loss = 0.2979
# iteration 23300: loss = 0.2979
# iteration 23350: loss = 0.2979
# iteration 23400: loss = 0.2979
# iteration 23450: loss = 0.2979
# iteration 23500: loss = 0.2979
# iteration 23550: loss = 0.2979
# iteration 23600: loss = 0.2979
# iteration 23650: loss = 0.2979
# iteration 23700: loss = 0.2979
# iteration 23750: loss = 0.2979
# iteration 23800: loss = 0.2979
# iteration 23850: loss = 0.2979
# iteration 23900: loss = 0.2979
# iteration 23950: loss = 0.2979
# iteration 24000: loss = 0.2979
# iteration 24050: loss = 0.2979
# iteration 24100: loss = 0.2979
# iteration 24150: loss = 0.2979
# iteration 24200: loss = 0.2979
# iteration 24250: loss = 0.2979
# iteration 24300: loss = 0.2979
# iteration 24350: loss = 0.2979
# iteration 24400: loss = 0.2979
# iteration 24450: loss = 0.2979
# iteration 24500: loss = 0.2979
# iteration 24550: loss = 0.2979
# iteration 24600: loss = 0.2979
# iteration 24650: loss = 0.2979
# iteration 24700: loss = 0.2979
# iteration 24750: loss = 0.2979
# iteration 24800: loss = 0.2979
# iteration 24850: loss = 0.2979
# iteration 24900: loss = 0.2979
# iteration 24950: loss = 0.2979
# iteration 25000: loss = 0.2979
# iteration 25050: loss = 0.2979
# iteration 25100: loss = 0.2979
# iteration 25150: loss = 0.2979
# iteration 25200: loss = 0.2979
# iteration 25250: loss = 0.2979
# iteration 25300: loss = 0.2979
# iteration 25350: loss = 0.2979
# iteration 25400: loss = 0.2979
# iteration 25450: loss = 0.2979
# iteration 25500: loss = 0.2979
# iteration 25550: loss = 0.2979
# iteration 25600: loss = 0.2979
# iteration 25650: loss = 0.2979
# iteration 25700: loss = 0.2979
# iteration 25750: loss = 0.2979
# iteration 25800: loss = 0.2979
# iteration 25850: loss = 0.2979
# iteration 25900: loss = 0.2979
# iteration 25950: loss = 0.2979
# iteration 26000: loss = 0.2979
# iteration 26050: loss = 0.2979
# iteration 26100: loss = 0.2979
# iteration 26150: loss = 0.2979
# iteration 26200: loss = 0.2979
# iteration 26250: loss = 0.2979
# iteration 26300: loss = 0.2979
# iteration 26350: loss = 0.2979
# iteration 26400: loss = 0.2979
# iteration 26450: loss = 0.2979
# iteration 26500: loss = 0.2979
# iteration 26550: loss = 0.2979
# iteration 26600: loss = 0.2979
# iteration 26650: loss = 0.2979
# iteration 26700: loss = 0.2979
# iteration 26750: loss = 0.2979
# iteration 26800: loss = 0.2979
# iteration 26850: loss = 0.2979
# iteration 26900: loss = 0.2979
# iteration 26950: loss = 0.2979
# iteration 27000: loss = 0.2979
# iteration 27050: loss = 0.2979
# iteration 27100: loss = 0.2979
# iteration 27150: loss = 0.2979
# iteration 27200: loss = 0.2979
# iteration 27250: loss = 0.2979
# iteration 27300: loss = 0.2979
# iteration 27350: loss = 0.2979
# iteration 27400: loss = 0.2979
# iteration 27450: loss = 0.2979
# iteration 27500: loss = 0.2979
# iteration 27550: loss = 0.2979
# iteration 27600: loss = 0.2979
# iteration 27650: loss = 0.2979
# iteration 27700: loss = 0.2979
# iteration 27750: loss = 0.2979
# iteration 27800: loss = 0.2979
# iteration 27850: loss = 0.2979
# iteration 27900: loss = 0.2979
# iteration 27950: loss = 0.2979
# iteration 28000: loss = 0.2979
# iteration 28050: loss = 0.2979
# iteration 28100: loss = 0.2979
# iteration 28150: loss = 0.2979
# iteration 28200: loss = 0.2979
# iteration 28250: loss = 0.2979
# iteration 28300: loss = 0.2979
# iteration 28350: loss = 0.2979
# iteration 28400: loss = 0.2979
# iteration 28450: loss = 0.2979
# iteration 28500: loss = 0.2979
# iteration 28550: loss = 0.2979
# iteration 28600: loss = 0.2979
# iteration 28650: loss = 0.2979
# iteration 28700: loss = 0.2979
# iteration 28750: loss = 0.2979
# iteration 28800: loss = 0.2979
# iteration 28850: loss = 0.2979
# iteration 28900: loss = 0.2979
# iteration 28950: loss = 0.2979
# iteration 29000: loss = 0.2979
# iteration 29050: loss = 0.2979
# iteration 29100: loss = 0.2979
# iteration 29150: loss = 0.2979
# iteration 29200: loss = 0.2979
# iteration 29250: loss = 0.2979
# iteration 29300: loss = 0.2979
# iteration 29350: loss = 0.2979
# iteration 29400: loss = 0.2979
# iteration 29450: loss = 0.2979
# iteration 29500: loss = 0.2979
# iteration 29550: loss = 0.2979
# iteration 29600: loss = 0.2979
# iteration 29650: loss = 0.2979
# iteration 29700: loss = 0.2979
# iteration 29750: loss = 0.2979
# iteration 29800: loss = 0.2979
# iteration 29850: loss = 0.2979
# iteration 29900: loss = 0.2979
# iteration 29950: loss = 0.2979
# iteration 30000: loss = 0.2979
# iteration 30050: loss = 0.2979
# iteration 30100: loss = 0.2979
# iteration 30150: loss = 0.2979
# iteration 30200: loss = 0.2979
# iteration 30250: loss = 0.2979
# iteration 30300: loss = 0.2979
# iteration 30350: loss = 0.2979
# iteration 30400: loss = 0.2979
# iteration 30450: loss = 0.2979
# iteration 30500: loss = 0.2979
# iteration 30550: loss = 0.2979
# iteration 30600: loss = 0.2979
# iteration 30650: loss = 0.2979
# iteration 30700: loss = 0.2979
# iteration 30750: loss = 0.2979
# iteration 30800: loss = 0.2979
# iteration 30850: loss = 0.2979
# iteration 30900: loss = 0.2979
# iteration 30950: loss = 0.2979
# iteration 31000: loss = 0.2979
# iteration 31050: loss = 0.2979
# iteration 31100: loss = 0.2979
# iteration 31150: loss = 0.2979
# iteration 31200: loss = 0.2979
# iteration 31250: loss = 0.2979
# iteration 31300: loss = 0.2979
# iteration 31350: loss = 0.2979
# iteration 31400: loss = 0.2979
# iteration 31450: loss = 0.2979
# iteration 31500: loss = 0.2979
# iteration 31550: loss = 0.2979
# iteration 31600: loss = 0.2979
# iteration 31650: loss = 0.2979
# iteration 31700: loss = 0.2979
# iteration 31750: loss = 0.2979
# iteration 31800: loss = 0.2979
# iteration 31850: loss = 0.2979
# iteration 31900: loss = 0.2979
# iteration 31950: loss = 0.2979
# iteration 32000: loss = 0.2979
# iteration 32050: loss = 0.2979
# iteration 32100: loss = 0.2979
# iteration 32150: loss = 0.2979
# iteration 32200: loss = 0.2979
# iteration 32250: loss = 0.2979
# iteration 32300: loss = 0.2979
# iteration 32350: loss = 0.2979
# iteration 32400: loss = 0.2979
# iteration 32450: loss = 0.2979
# iteration 32500: loss = 0.2979
# iteration 32550: loss = 0.2979
# iteration 32600: loss = 0.2979
# iteration 32650: loss = 0.2979
# iteration 32700: loss = 0.2979
# iteration 32750: loss = 0.2979
# iteration 32800: loss = 0.2979
# iteration 32850: loss = 0.2979
# iteration 32900: loss = 0.2979
# iteration 32950: loss = 0.2979
# iteration 33000: loss = 0.2979
# iteration 33050: loss = 0.2979
# iteration 33100: loss = 0.2979
# iteration 33150: loss = 0.2979
# iteration 33200: loss = 0.2979
# iteration 33250: loss = 0.2979
# iteration 33300: loss = 0.2979
# iteration 33350: loss = 0.2979
# iteration 33400: loss = 0.2979
# iteration 33450: loss = 0.2979
# iteration 33500: loss = 0.2979
# iteration 33550: loss = 0.2979
# iteration 33600: loss = 0.2979
# iteration 33650: loss = 0.2979
# iteration 33700: loss = 0.2979
# iteration 33750: loss = 0.2979
# iteration 33800: loss = 0.2979
# iteration 33850: loss = 0.2979
# iteration 33900: loss = 0.2979
# iteration 33950: loss = 0.2979
# iteration 34000: loss = 0.2979
# iteration 34050: loss = 0.2979
# iteration 34100: loss = 0.2979
# iteration 34150: loss = 0.2979
# iteration 34200: loss = 0.2979
# iteration 34250: loss = 0.2979
# iteration 34300: loss = 0.2979
# iteration 34350: loss = 0.2979
# iteration 34400: loss = 0.2979
# iteration 34450: loss = 0.2979
# iteration 34500: loss = 0.2979
# iteration 34550: loss = 0.2979
# iteration 34600: loss = 0.2979
# iteration 34650: loss = 0.2979
# iteration 34700: loss = 0.2979
# iteration 34750: loss = 0.2979
# iteration 34800: loss = 0.2979
# iteration 34850: loss = 0.2979
# iteration 34900: loss = 0.2979
# iteration 34950: loss = 0.2979
# iteration 35000: loss = 0.2979
# iteration 35050: loss = 0.2979
# iteration 35100: loss = 0.2979
# iteration 35150: loss = 0.2979
# iteration 35200: loss = 0.2979
# iteration 35250: loss = 0.2979
# iteration 35300: loss = 0.2979
# iteration 35350: loss = 0.2979
# iteration 35400: loss = 0.2979
# iteration 35450: loss = 0.2979
# iteration 35500: loss = 0.2979
# iteration 35550: loss = 0.2979
# iteration 35600: loss = 0.2979
# iteration 35650: loss = 0.2979
# iteration 35700: loss = 0.2979
# iteration 35750: loss = 0.2979
# iteration 35800: loss = 0.2979
# iteration 35850: loss = 0.2979
# iteration 35900: loss = 0.2979
# iteration 35950: loss = 0.2979
# iteration 36000: loss = 0.2979
# iteration 36050: loss = 0.2979
# iteration 36100: loss = 0.2979
# iteration 36150: loss = 0.2979
# iteration 36200: loss = 0.2979
# iteration 36250: loss = 0.2979
# iteration 36300: loss = 0.2979
# iteration 36350: loss = 0.2979
# iteration 36400: loss = 0.2979
# iteration 36450: loss = 0.2979
# iteration 36500: loss = 0.2979
# iteration 36550: loss = 0.2979
# iteration 36600: loss = 0.2979
# iteration 36650: loss = 0.2979
# iteration 36700: loss = 0.2979
# iteration 36750: loss = 0.2979
# iteration 36800: loss = 0.2979
# iteration 36850: loss = 0.2979
# iteration 36900: loss = 0.2979
# iteration 36950: loss = 0.2979
# iteration 37000: loss = 0.2979
# iteration 37050: loss = 0.2979
# iteration 37100: loss = 0.2979
# iteration 37150: loss = 0.2979
# iteration 37200: loss = 0.2979
# iteration 37250: loss = 0.2979
# iteration 37300: loss = 0.2979
# iteration 37350: loss = 0.2979
# iteration 37400: loss = 0.2979
# iteration 37450: loss = 0.2979
# iteration 37500: loss = 0.2979
# iteration 37550: loss = 0.2979
# iteration 37600: loss = 0.2979
# iteration 37650: loss = 0.2979
# iteration 37700: loss = 0.2979
# iteration 37750: loss = 0.2979
# iteration 37800: loss = 0.2979
# iteration 37850: loss = 0.2979
# iteration 37900: loss = 0.2979
# iteration 37950: loss = 0.2979
# iteration 38000: loss = 0.2979
# iteration 38050: loss = 0.2979
# iteration 38100: loss = 0.2979
# iteration 38150: loss = 0.2979
# iteration 38200: loss = 0.2979
# iteration 38250: loss = 0.2979
# iteration 38300: loss = 0.2979
# iteration 38350: loss = 0.2979
# iteration 38400: loss = 0.2979
# iteration 38450: loss = 0.2979
# iteration 38500: loss = 0.2979
# iteration 38550: loss = 0.2979
# iteration 38600: loss = 0.2979
# iteration 38650: loss = 0.2979
# iteration 38700: loss = 0.2979
# iteration 38750: loss = 0.2979
# iteration 38800: loss = 0.2979
# iteration 38850: loss = 0.2979
# iteration 38900: loss = 0.2979
# iteration 38950: loss = 0.2979
# iteration 39000: loss = 0.2979
# iteration 39050: loss = 0.2979
# iteration 39100: loss = 0.2979
# iteration 39150: loss = 0.2979
# iteration 39200: loss = 0.2979
# iteration 39250: loss = 0.2979
# iteration 39300: loss = 0.2979
# iteration 39350: loss = 0.2979
# iteration 39400: loss = 0.2979
# iteration 39450: loss = 0.2979
# iteration 39500: loss = 0.2979
# iteration 39550: loss = 0.2979
# iteration 39600: loss = 0.2979
# iteration 39650: loss = 0.2979
# iteration 39700: loss = 0.2979
# iteration 39750: loss = 0.2979
# iteration 39800: loss = 0.2979
# iteration 39850: loss = 0.2979
# iteration 39900: loss = 0.2979
# iteration 39950: loss = 0.2979
# iteration 40000: loss = 0.2979
# iteration 40050: loss = 0.2979
# iteration 40100: loss = 0.2979
# iteration 40150: loss = 0.2979
# iteration 40200: loss = 0.2979
# iteration 40250: loss = 0.2979
# iteration 40300: loss = 0.2979
# iteration 40350: loss = 0.2979
# iteration 40400: loss = 0.2979
# iteration 40450: loss = 0.2979
# iteration 40500: loss = 0.2979
# iteration 40550: loss = 0.2979
# iteration 40600: loss = 0.2979
# iteration 40650: loss = 0.2979
# iteration 40700: loss = 0.2979
# iteration 40750: loss = 0.2979
# iteration 40800: loss = 0.2979
# iteration 40850: loss = 0.2979
# iteration 40900: loss = 0.2979
# iteration 40950: loss = 0.2979
# iteration 41000: loss = 0.2979
# iteration 41050: loss = 0.2979
# iteration 41100: loss = 0.2979
# iteration 41150: loss = 0.2979
# iteration 41200: loss = 0.2979
# iteration 41250: loss = 0.2979
# iteration 41300: loss = 0.2979
# iteration 41350: loss = 0.2979
# iteration 41400: loss = 0.2979
# iteration 41450: loss = 0.2979
# iteration 41500: loss = 0.2979
# iteration 41550: loss = 0.2979
# iteration 41600: loss = 0.2979
# iteration 41650: loss = 0.2979
# iteration 41700: loss = 0.2979
# iteration 41750: loss = 0.2979
# iteration 41800: loss = 0.2979
# iteration 41850: loss = 0.2979
# iteration 41900: loss = 0.2979
# iteration 41950: loss = 0.2979
# iteration 42000: loss = 0.2979
# iteration 42050: loss = 0.2979
# iteration 42100: loss = 0.2979
# iteration 42150: loss = 0.2979
# iteration 42200: loss = 0.2979
# iteration 42250: loss = 0.2979
# iteration 42300: loss = 0.2979
# iteration 42350: loss = 0.2979
# iteration 42400: loss = 0.2979
# iteration 42450: loss = 0.2979
# iteration 42500: loss = 0.2979
# iteration 42550: loss = 0.2979
# iteration 42600: loss = 0.2979
# iteration 42650: loss = 0.2979
# iteration 42700: loss = 0.2979
# iteration 42750: loss = 0.2979
# iteration 42800: loss = 0.2979
# iteration 42850: loss = 0.2979
# iteration 42900: loss = 0.2979
# iteration 42950: loss = 0.2979
# iteration 43000: loss = 0.2979
# iteration 43050: loss = 0.2979
# iteration 43100: loss = 0.2979
# iteration 43150: loss = 0.2979
# iteration 43200: loss = 0.2979
# iteration 43250: loss = 0.2979
# iteration 43300: loss = 0.2979
# iteration 43350: loss = 0.2979
# iteration 43400: loss = 0.2979
# iteration 43450: loss = 0.2979
# iteration 43500: loss = 0.2979
# iteration 43550: loss = 0.2979
# iteration 43600: loss = 0.2979
# iteration 43650: loss = 0.2979
# iteration 43700: loss = 0.2979
# iteration 43750: loss = 0.2979
# iteration 43800: loss = 0.2979
# iteration 43850: loss = 0.2979
# iteration 43900: loss = 0.2979
# iteration 43950: loss = 0.2979
# iteration 44000: loss = 0.2979
# iteration 44050: loss = 0.2979
# iteration 44100: loss = 0.2979
# iteration 44150: loss = 0.2979
# iteration 44200: loss = 0.2979
# iteration 44250: loss = 0.2979
# iteration 44300: loss = 0.2979
# iteration 44350: loss = 0.2979
# iteration 44400: loss = 0.2979
# iteration 44450: loss = 0.2979
# iteration 44500: loss = 0.2979
# iteration 44550: loss = 0.2979
# iteration 44600: loss = 0.2979
# iteration 44650: loss = 0.2979
# iteration 44700: loss = 0.2979
# iteration 44750: loss = 0.2979
# iteration 44800: loss = 0.2979
# iteration 44850: loss = 0.2979
# iteration 44900: loss = 0.2979
# iteration 44950: loss = 0.2979
# iteration 45000: loss = 0.2979
# iteration 45050: loss = 0.2979
# iteration 45100: loss = 0.2979
# iteration 45150: loss = 0.2979
# iteration 45200: loss = 0.2979
# iteration 45250: loss = 0.2979
# iteration 45300: loss = 0.2979
# iteration 45350: loss = 0.2979
# iteration 45400: loss = 0.2979
# iteration 45450: loss = 0.2979
# iteration 45500: loss = 0.2979
# iteration 45550: loss = 0.2979
# iteration 45600: loss = 0.2979
# iteration 45650: loss = 0.2979
# iteration 45700: loss = 0.2979
# iteration 45750: loss = 0.2979
# iteration 45800: loss = 0.2979
# iteration 45850: loss = 0.2979
# iteration 45900: loss = 0.2979
# iteration 45950: loss = 0.2979
# iteration 46000: loss = 0.2979
# iteration 46050: loss = 0.2979
# iteration 46100: loss = 0.2979
# iteration 46150: loss = 0.2979
# iteration 46200: loss = 0.2979
# iteration 46250: loss = 0.2979
# iteration 46300: loss = 0.2979
# iteration 46350: loss = 0.2979
# iteration 46400: loss = 0.2979
# iteration 46450: loss = 0.2979
# iteration 46500: loss = 0.2979
# iteration 46550: loss = 0.2979
# iteration 46600: loss = 0.2979
# iteration 46650: loss = 0.2979
# iteration 46700: loss = 0.2979
# iteration 46750: loss = 0.2979
# iteration 46800: loss = 0.2979
# iteration 46850: loss = 0.2979
# iteration 46900: loss = 0.2979
# iteration 46950: loss = 0.2979
# iteration 47000: loss = 0.2979
# iteration 47050: loss = 0.2979
# iteration 47100: loss = 0.2979
# iteration 47150: loss = 0.2979
# iteration 47200: loss = 0.2979
# iteration 47250: loss = 0.2979
# iteration 47300: loss = 0.2979
# iteration 47350: loss = 0.2979
# iteration 47400: loss = 0.2979
# iteration 47450: loss = 0.2979
# iteration 47500: loss = 0.2979
# iteration 47550: loss = 0.2979
# iteration 47600: loss = 0.2979
# iteration 47650: loss = 0.2979
# iteration 47700: loss = 0.2979
# iteration 47750: loss = 0.2979
# iteration 47800: loss = 0.2979
# iteration 47850: loss = 0.2979
# iteration 47900: loss = 0.2979
# iteration 47950: loss = 0.2979
# iteration 48000: loss = 0.2979
# iteration 48050: loss = 0.2979
# iteration 48100: loss = 0.2979
# iteration 48150: loss = 0.2979
# iteration 48200: loss = 0.2979
# iteration 48250: loss = 0.2979
# iteration 48300: loss = 0.2979
# iteration 48350: loss = 0.2979
# iteration 48400: loss = 0.2979
# iteration 48450: loss = 0.2979
# iteration 48500: loss = 0.2979
# iteration 48550: loss = 0.2979
# iteration 48600: loss = 0.2979
# iteration 48650: loss = 0.2979
# iteration 48700: loss = 0.2979
# iteration 48750: loss = 0.2979
# iteration 48800: loss = 0.2979
# iteration 48850: loss = 0.2979
# iteration 48900: loss = 0.2979
# iteration 48950: loss = 0.2979
# iteration 49000: loss = 0.2979
# iteration 49050: loss = 0.2979
# iteration 49100: loss = 0.2979
# iteration 49150: loss = 0.2979
# iteration 49200: loss = 0.2979
# iteration 49250: loss = 0.2979
# iteration 49300: loss = 0.2979
# iteration 49350: loss = 0.2979
# iteration 49400: loss = 0.2979
# iteration 49450: loss = 0.2979
# iteration 49500: loss = 0.2979
# iteration 49550: loss = 0.2979
# iteration 49600: loss = 0.2979
# iteration 49650: loss = 0.2979
# iteration 49700: loss = 0.2979
# iteration 49750: loss = 0.2979
# iteration 49800: loss = 0.2979
# iteration 49850: loss = 0.2979
# iteration 49900: loss = 0.2979
# iteration 49950: loss = 0.2979
# iteration 50000: loss = 0.2979
# w and b estimates:
#     4.5327
#     -4.6715
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]

# %% [markdown]
# ***
# ### Q6: Run the above code a cell a few times and then try changing the learning rate above to a larger value. How many epochs are then needed to get the loss below 0.10? Is it possible to get the loss below 0.05?
#
# \<INPUT YOUR ANSWER TO Q6 HERE\>
# ***
# After changing the learning rate to 0.2 I was able to get the loss below 0.1 within the 20 to 50 epoch range. However, after experimenting with the initial program for a while and reaching a wall with learning rates of 0.1 to 1.0 and upwards of 5000 epochs for fun I realized that each loss function would eventually reach a wall that could not be surpassed. Thus making it not possible to drop below a loss value of 0.05.

# %% [markdown]
# ### 6. Using PyTorch's torch.nn.Module Base Class
# Finally, let's make use of the PyTorch base class for creating a neural network. The `torch.nn.Module` class is the base class that we will inherit from to create a neural network. Notice that to start we override the constructor, `__init__`, and that inside this method we define the various layers to our neural network. We can then define the `forward` method to behave specifically how we choose. In the example below we pass an additional flag to the `forward()` method to either calculate and return the final predicted probability (with `apply_sigmoid=True`) or to simply return the linear predictor (with `apply_sigmoid=False`). This can be useful for us in some instances. For example, the log-loss function (aka binary cross-entropy) can execute slightly more efficiently by taking advantage of the fact that the `log` and `exp` functions are inverses of one another (recall that the sigmoid function has `exp()` in it).

# %%
# Randomly initialize weights and other data
torch.manual_seed(42)
#w = torch.randn(1, requires_grad=True).reshape(1,1)
#b = torch.randn(1, requires_grad=True).reshape(1,1)
x_tensor = torch.tensor(x).float()
y_tensor = torch.tensor(y).float().reshape(N, D_out)

# Define our own ANN class
class Perceptron(torch.nn.Module):
    def __init__(self, input_dim):
        super(Perceptron, self).__init__()
        self.lay1 = torch.nn.Linear(input_dim, 1) # linear layer
        self.act = torch.nn.Sigmoid()             # activation layer
    def forward(self, x, apply_sigmoid=False):
        output = self.lay1(x)
        if apply_sigmoid:
            output = self.act(output)
        return output

model = Perceptron(1)

# Define loss function to be used
#loss_fn = torch.nn.MSELoss()
loss_fn = torch.nn.BCELoss()
#loss_fn = torch.nn.BCEWithLogitsLoss() # expects only linear predictor (w/o sigmoid applied)
learning_rate = 5e-1

# define optimizer to be used and tell it about the model's parameters
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
losses = []
params = []

# Carry out gradient descent
for i in range(200+1):

    params.append(tuple([param.item() for param in model.parameters()]))

    # Forward pass: compute predicted y
    y_pred = model.forward(x_tensor, apply_sigmoid=True) #False)

    # Compute and store loss, and print occassionally
    loss = loss_fn(y_pred, y_tensor)

    losses.append(loss.item())
    if i % 50 == 0:
        print(f"iteration {i}: loss = {loss.item():.4f}") #" w = {w[0]:.4f}, b = {b[0]:.4f}")

    # Zero all gradients before backward pass
    optimizer.zero_grad()

    # Backpropagation: calculate loss for each model parameter and have optimizer update all of them
    loss.backward()
    optimizer.step()

print("w and b estimates:")
for param in model.parameters():
    print(f"   {param.item():.4f}")

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,4))
ax1.plot(range(0,len(losses)), losses)
ax1.set(xlabel="optimization iteration", ylabel="loss")
ax2.plot(range(0,len(params)), [parm[0] for parm in params])
ax2.set(xlabel="optimization iteration", ylabel="parameter: w")
ax3.plot(range(0,len(params)), [parm[1] for parm in params])
ax3.set(xlabel="optimization iteration", ylabel="parameter: b")
# Out:
# iteration 0: loss = 0.7997
# iteration 50: loss = 0.3000
# iteration 100: loss = 0.2979
# iteration 150: loss = 0.2979
# iteration 200: loss = 0.2979
# w and b estimates:
#    4.5328
#    -4.6717
# [Text(0.5, 0, 'optimization iteration'), Text(0, 0.5, 'parameter: b')]
